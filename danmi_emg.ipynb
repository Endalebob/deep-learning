# %% [markdown]
# <a href="https://colab.research.google.com/github/Endalebob/deep-learning/blob/main/danmi_emg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import csv
import numpy as np

# Load the data
file_path = '/content/final_emg_data.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
df.head()
# Out:
#    Channel1  Channel2  Channel3   label     person
# 0       177       282       355  clinch   Habib Gm
# 1       169       135        38  clinch  Liban Abd
# 2       163       131        36  clinch  Liban Abd
# 3       156       126        34  clinch  Liban Abd
# 4       157       121        33  clinch  Liban Abd

# %%
# @title Channel1

from matplotlib import pyplot as plt
df['Channel1'].plot(kind='hist', bins=20, title='Channel1')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Channel2

from matplotlib import pyplot as plt
df['Channel2'].plot(kind='hist', bins=20, title='Channel2')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Channel3

from matplotlib import pyplot as plt
df['Channel3'].plot(kind='hist', bins=20, title='Channel3')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title person

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('person').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title label

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('label').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Channel1

from matplotlib import pyplot as plt
df['Channel1'].plot(kind='line', figsize=(8, 4), title='Channel1')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Channel2

from matplotlib import pyplot as plt
df['Channel2'].plot(kind='line', figsize=(8, 4), title='Channel2')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Channel3

from matplotlib import pyplot as plt
df['Channel3'].plot(kind='line', figsize=(8, 4), title='Channel3')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title label vs Channel1

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['label'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Channel1', y='label', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-10-5a511de2c596>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Channel1', y='label', inner='box', palette='Dark2')

# %%
# @title label vs Channel2

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['label'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Channel2', y='label', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-11-ab28c14d9caf>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Channel2', y='label', inner='box', palette='Dark2')

# %%
# @title label vs Channel3

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['label'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Channel3', y='label', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-12-b97f6d419917>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Channel3', y='label', inner='box', palette='Dark2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check for missing values
print(df.isnull().sum())

# Summary statistics
print(df.describe())

# Distribution of labels
plt.figure(figsize=(10, 6))
sns.countplot(x='label', data=df)
plt.title('Distribution of Gestures')
plt.show()

# Plot some sample data from each gesture
fig, axes = plt.subplots(3, 1, figsize=(15, 12))
gestures = ['clinch', 'ingera', 'ok']
for i, gesture in enumerate(gestures):
    subset = df[df['label'] == gesture].iloc[:100]
    axes[i].plot(subset['Channel1'], label='Channel1')
    axes[i].plot(subset['Channel2'], label='Channel2')
    axes[i].plot(subset['Channel3'], label='Channel3')
    axes[i].set_title(f'{gesture.capitalize()} Gesture')
    axes[i].legend()
plt.tight_layout()
plt.show()
# Out:
# Channel1    0
# Channel2    0
# Channel3    0
# label       0
# person      0
# dtype: int64
#             Channel1       Channel2       Channel3
# count  131291.000000  131291.000000  131291.000000
# mean       67.549581      96.594291      44.540045
# std        79.646167      95.730401      50.025911
# min         0.000000       0.000000       1.000000
# 25%         9.000000       1.000000      11.000000
# 50%        40.000000      82.000000      29.000000
# 75%        96.000000     162.000000      55.000000
# max       670.000000     615.000000     537.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131291 entries, 0 to 131290
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Channel1  131291 non-null  int64
#  1   Channel2  131291 non-null  int64
#  2   Channel3  131291 non-null  int64
#  3   label     131291 non-null  object
#  4   person    131291 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 5.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Encode 'label' column
df['label'] = label_encoder.fit_transform(df['label'])

# Encode 'person' column
df['person'] = label_encoder.fit_transform(df['person'])

# %%
df.head()
# Out:
#    Channel1  Channel2  Channel3  label  person
# 0       177       282       355      0       5
# 1       169       135        38      0       8
# 2       163       131        36      0       8
# 3       156       126        34      0       8
# 4       157       121        33      0       8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131291 entries, 0 to 131290
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Channel1  131291 non-null  int64
#  1   Channel2  131291 non-null  int64
#  2   Channel3  131291 non-null  int64
#  3   label     131291 non-null  int64
#  4   person    131291 non-null  int64
# dtypes: int64(5)
# memory usage: 5.0 MB

# %%
data = df
data.drop('person', inplace=True, axis=1)

# %%
def normalized(data):
    min_value = np.min(data)
    max_value = np.max(data)
    normalized_data = (data - min_value) / (max_value - min_value)
    return normalized_data

# %%
import numpy as np

def sliding_window(data, window_size, stride):
    windowed_data = []
    labels = []

    for i in range(0, len(data) - window_size + 1, stride):
        windowed = data.iloc[i:i+window_size, :-1].values  # Exclude the label column and convert to NumPy array
        label = data.iloc[i+window_size-1, -1]  # Use the last column as the label
        windowed_data.append(windowed)
        labels.append(label)

    return np.array(windowed_data), np.array(labels)

# %%
window_size=150
stride=30
X, Y = sliding_window(data, 150, 30)

# %%
X = normalized(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

def CNN_model(input_shape, num_classes):
    model = Sequential()

    # Convolutional layers
    model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # Flattening layers
    model.add(Flatten())

    # Full connected layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    # compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# %%
# define the CNN model
input_shape = X_train.shape[1:]  # set input size
num_classes = len(np.unique(Y))   # set class size

model = CNN_model(input_shape, num_classes)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 148, 32)           320
#
#  max_pooling1d (MaxPooling1  (None, 74, 32)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 72, 64)            6208
#
#  max_pooling1d_1 (MaxPoolin  (None, 36, 64)            0
#  g1D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dense_1 (Dense)             (None, 4)                 516
#
# ...
# Total params: 302084 (1.15 MB)
# Trainable params: 302084 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=12, validation_data=(X_test, y_test))
# Out:
# Epoch 1/12
# 110/110 [==============================] - 4s 21ms/step - loss: 0.5765 - accuracy: 0.7727 - val_loss: 0.3684 - val_accuracy: 0.8606
# Epoch 2/12
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3344 - accuracy: 0.8690 - val_loss: 0.3227 - val_accuracy: 0.8811
# Epoch 3/12
# 110/110 [==============================] - 2s 17ms/step - loss: 0.2804 - accuracy: 0.8842 - val_loss: 0.2581 - val_accuracy: 0.8846
# Epoch 4/12
# 110/110 [==============================] - 2s 18ms/step - loss: 0.2580 - accuracy: 0.8933 - val_loss: 0.2509 - val_accuracy: 0.8869
# Epoch 5/12
# 110/110 [==============================] - 3s 28ms/step - loss: 0.2443 - accuracy: 0.9002 - val_loss: 0.3248 - val_accuracy: 0.8674
# Epoch 6/12
# 110/110 [==============================] - 2s 20ms/step - loss: 0.2381 - accuracy: 0.8996 - val_loss: 0.2328 - val_accuracy: 0.8960
# Epoch 7/12
# ...

# %%
from sklearn.metrics import accuracy_score, f1_score
import numpy as np

# Make predictions on training data
y_pred_train = model.predict(X_train)
y_pred_train = np.argmax(y_pred_train, axis=1)  # Convert from one-hot encoding to labels

# Make predictions on test data
y_pred_test = model.predict(X_test)
y_pred_test = np.argmax(y_pred_test, axis=1)  # Convert from one-hot encoding to labels

# Calculate accuracy
accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test, y_pred_test)

# Calculate F1 score
f1_train = f1_score(y_train, y_pred_train, average='weighted')
f1_test = f1_score(y_test, y_pred_test, average='weighted')

print("Training Accuracy:", accuracy_train)
print("Test Accuracy:", accuracy_test)
print("Training F1 Score:", f1_train)
print("Test F1 Score:", f1_test)
# Out:
# ...
# 28/28 [==============================] - 0s 5ms/step
# Training Accuracy: 0.9433800400343151
# Test Accuracy: 0.9257142857142857
# Training F1 Score: 0.9441769590961888
# Test F1 Score: 0.9260606954348178

# %%
import matplotlib.pyplot as plt

# Training and testing loss graph
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.title('Confusion Matrix SW')
plt.xlabel('Predicted Labels SW')
plt.ylabel('Real Labels SW')
plt.show()

# %%
from sklearn.metrics import classification_report

# accuracy and F1 score of classes
rapor = classification_report(y_test, y_pred_test, target_names=[str(i) for i in np.unique(y_test)])
print(rapor)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       201
#            1       0.81      0.93      0.87       180
#            2       0.93      0.84      0.88       230
#            3       1.00      1.00      1.00       264
#
#     accuracy                           0.93       875
#    macro avg       0.92      0.92      0.92       875
# weighted avg       0.93      0.93      0.93       875

# %%
import numpy as np
from scipy.fft import fft
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

def fourier_transform(X):
    transformed_data = []

    for item in X:
        transformed_item = []
        for channel in item.T:  # transpose the data and apply Fourier transform to each channel separately
            fft_values = fft(channel)
            transformed_item.append(np.abs(fft_values))  # only use amplitude information

        transformed_data.append(np.array(transformed_item))

    return np.array(transformed_data)

# %%
# apply fourier transform
transformed_X = fourier_transform(X)

# %%
transpoze_X = np.transpose(transformed_X, (0, 2, 1))

# %%
# split the data into training and testing sets
X_train_ft, X_test_ft, y_train_ft, y_test_ft = train_test_split(transpoze_X, Y, test_size=0.3, random_state=42)

# %%
# define CNN model
input_shape = X_train_ft.shape[1:]  # set input size
num_classes = len(np.unique(Y))   # set class size

model_ft = CNN_model(input_shape, num_classes)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_2 (Conv1D)           (None, 148, 32)           320
#
#  max_pooling1d_2 (MaxPoolin  (None, 74, 32)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 72, 64)            6208
#
#  max_pooling1d_3 (MaxPoolin  (None, 36, 64)            0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 128)               295040
#
#  dense_3 (Dense)             (None, 4)                 516
#
# ...
# Total params: 302084 (1.15 MB)
# Trainable params: 302084 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_ft = model_ft.fit(X_train_ft, y_train_ft, epochs=12, validation_data=(X_test_ft, y_test_ft))
# Out:
# Epoch 1/7
# 96/96 [==============================] - 3s 22ms/step - loss: 0.6103 - accuracy: 0.7690 - val_loss: 0.3446 - val_accuracy: 0.8689
# Epoch 2/7
# 96/96 [==============================] - 2s 19ms/step - loss: 0.2659 - accuracy: 0.9033 - val_loss: 0.1994 - val_accuracy: 0.9345
# Epoch 3/7
# 96/96 [==============================] - 2s 23ms/step - loss: 0.1762 - accuracy: 0.9451 - val_loss: 0.1596 - val_accuracy: 0.9375
# Epoch 4/7
# 96/96 [==============================] - 3s 29ms/step - loss: 0.1173 - accuracy: 0.9667 - val_loss: 0.1077 - val_accuracy: 0.9649
# Epoch 5/7
# 96/96 [==============================] - 2s 23ms/step - loss: 0.0805 - accuracy: 0.9758 - val_loss: 0.1048 - val_accuracy: 0.9657
# Epoch 6/7
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0574 - accuracy: 0.9853 - val_loss: 0.0941 - val_accuracy: 0.9672
# Epoch 7/7
# ...

# %%
from sklearn.metrics import accuracy_score, f1_score
import numpy as np

# Make predictions on training data
y_pred_train_ft = model_ft.predict(X_train_ft)
y_pred_train_ft = np.argmax(y_pred_train_ft, axis=1)  # Convert from one-hot encoding to labels

# Make predictions on test data
y_pred_test_ft = model_ft.predict(X_test_ft)
y_pred_test_ft = np.argmax(y_pred_test_ft, axis=1)  # Convert from one-hot encoding to labels

# Calculate accuracy
accuracy_train_ft = accuracy_score(y_train_ft, y_pred_train_ft)
accuracy_test_ft = accuracy_score(y_test_ft, y_pred_test_ft)

# Calculate F1 score
f1_train_ft = f1_score(y_train_ft, y_pred_train_ft, average='weighted')
f1_test_ft = f1_score(y_test_ft, y_pred_test_ft, average='weighted')

print("Training Accuracy FT:", accuracy_train_ft)
print("Test Accuracy FT:", accuracy_test_ft)
print("Training F1 Score FT:", f1_train_ft)
print("Test F1 Score FT:", f1_test_ft)
# Out:
# ...
# 41/41 [==============================] - 0s 6ms/step
# Training Accuracy FT: 0.9888888888888889
# Test Accuracy FT: 0.9702743902439024
# Training F1 Score FT: 0.9888997831437883
# Test F1 Score FT: 0.970331732627705

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test_ft, y_pred_test_ft)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_test_ft), yticklabels=np.unique(y_test_ft))
plt.title('Confusion Matrix SW')
plt.xlabel('Predicted Labels SW')
plt.ylabel('Real Labels SW')
plt.show()

# %%
from sklearn.metrics import classification_report

# accuracy and F1 score of classes
rapor_ft = classification_report(y_test_ft, y_pred_test_ft, target_names=[str(i) for i in np.unique(y_test)])
print(rapor_ft)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       297
#            1       0.98      0.94      0.96       270
#            2       0.93      0.99      0.95       342
#            3       0.99      1.00      0.99       403
#
#     accuracy                           0.97      1312
#    macro avg       0.97      0.97      0.97      1312
# weighted avg       0.97      0.97      0.97      1312
